# %% [markdown]
# # Set up the Lakehouse target table (lab)
#
# Attach `lh_meridian_hr` as the default lakehouse, then run this notebook before the event-ingestion pipeline. The DDL is idempotent and safely pre-creates the shared Delta table before parallel Copy activities append to it.
#
# > This is the **lab** version of `nb_00_setup_lakehouse.ipynb`. Each code cell below is a placeholder — replace the `# TODO` comments with your own working code, using the markdown cell above it as a guide.

# %% [markdown]
# ## Create the schema and pre-create the target table
#
# **Summary.** Ensure the `bronze` schema exists and pre-create the empty `bronze.workforce_events_raw` Delta table with an explicit column layout, so the pipeline's parallel Copy activities append to a table that already exists instead of racing to create it.

# %%
# TODO: Create the bronze schema and pre-create the empty target Delta table.
# - Create the `bronze` schema if it doesn't already exist.
# - Create `bronze.workforce_events_raw` only if it is missing (idempotent DDL) with an
#   explicit column layout: identifiers, event_date, classification columns, event_type,
#   pay amount + currency, work_country_code, and lineage columns (ingest_ts, source_system).
# - Store it USING DELTA so downstream appends are ACID.
# - Print a short confirmation message.
